# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency, ttest_ind
import sys
import os
sys.path.append(os.path.abspath('../scripts'))

# %%
from AB_Hypothesis_Testing import gender_analysis, Province_vs_TotalPremium_analysis, gender_vs_zip_codes, PostalCode_analysis, calculate_margin

# %%
df = pd.read_csv(r"C:\Users\ephre\Documents\AlphaCare-Insurance-Solutions\Data\MachineLearningRating_v3\cleaned_dataset.csv")
df.head()
# Out:
# C:\Users\ephre\AppData\Local\Temp\ipykernel_29920\143477589.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\ephre\Documents\AlphaCare-Insurance-Solutions\Data\MachineLearningRating_v3\cleaned_dataset.csv")
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# 0  Current account  ...             Mobility - Windscreen    Windscreen
# 1  Current account  ...             Mobility - Windscreen    Windscreen
# 2  Current account  ...             Mobility - Windscreen    Windscreen
# 3  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#    TotalPremium TotalClaims
# 0     21.929825         0.0
# 1     21.929825         0.0
# 2      0.000000         0.0
# 3    512.848070         0.0
# 4      0.000000         0.0
#
# [5 rows x 46 columns]

# %%
t_stat, p_value = gender_analysis(df)

# %%
print("T-statistic (Gender):", t_stat)
print("P-value (Gender):", p_value)
# Out:
# T-statistic (Gender): 0.2170914922683923
# P-value (Gender): 0.8281458574363545

# %%
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the groups.")
# Out:
# Fail to reject the null hypothesis: No significant difference between the groups.

# %%
Province_t_stat, Province_p_value = Province_vs_TotalPremium_analysis(df)
print("T-statistic (Province):", Province_t_stat)
print("P-value (Province):", Province_p_value)
# Out:
# T-statistic (Province): 0.2170914922683923
# P-value (Province): 0.8281458574363545

# %%
alpha = 0.05  # significance level
if Province_p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the groups.")
# Out:
# Fail to reject the null hypothesis: No significant difference between the groups.

# %%
zip_codes_t_stat, zip_codes_p_value = gender_vs_zip_codes(df)

# %%
print("T-statistic (zip_codes):", zip_codes_t_stat)
print("P-value (zip_codes):", zip_codes_p_value)
# Out:
# T-statistic (zip_codes): 39.36144040594415
# P-value (zip_codes): 9.561754217795647e-285

# %%
alpha = 0.05  # significance level
if zip_codes_p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the groups.")
# Out:
# Reject the null hypothesis: There is a significant difference between the groups.

# %%
df["ProfitMargin"] = calculate_margin(df)
df_clearned = df.dropna(subset=["ProfitMargin"])
df_clearned.sample(7)
# Out:
#         UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 522978               148006     13177  2015-06-01 00:00:00            False
# 294721               136273     10591  2015-07-01 00:00:00            False
# 468534               154755     13379  2015-08-01 00:00:00            False
# 638159                69108      5351  2014-09-01 00:00:00            False
# 95457                124450     10540  2015-02-01 00:00:00            False
# 505277               141575      8630  2015-07-01 00:00:00            False
# 700836                20069      1087  2015-04-01 00:00:00            False
#
#        Citizenship        LegalType Title Language                 Bank  \
# 522978                   Individual    Mr  English        Standard Bank
# 294721                   Individual    Mr  English  First National Bank
# 468534                   Individual    Mr  English        Standard Bank
# 638159              Private company    Mr  English  First National Bank
# 95457                    Individual    Mr  English            ABSA Bank
# 505277                   Individual    Mr  English        Standard Bank
# 700836          ZA       Individual    Mr  English  First National Bank
#
#             AccountType  ...                            CoverCategory  \
# 522978  Current account  ...  Cleaning and Removal of Accident Debris
# 294721  Current account  ...                               Windscreen
# 468534  Current account  ...  Cleaning and Removal of Accident Debris
# 638159  Current account  ...                              Third Party
# 95457   Savings account  ...                      Passenger Liability
# 505277  Current account  ...  Cleaning and Removal of Accident Debris
# 700836  Savings account  ...                      Passenger Liability
#
#                                       CoverType            CoverGroup  \
# 522978  Cleaning and Removal of Accident Debris  Comprehensive - Taxi
# 294721                               Windscreen  Comprehensive - Taxi
# 468534  Cleaning and Removal of Accident Debris  Comprehensive - Taxi
# 638159                              Third Party  Comprehensive - Taxi
# 95457                       Passenger Liability  Comprehensive - Taxi
# 505277  Cleaning and Removal of Accident Debris  Comprehensive - Taxi
# 700836                      Passenger Liability  Comprehensive - Taxi
#
#                     Section                             Product  \
# 522978  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 294721  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 468534  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 638159  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 95457   Motor Comprehensive  Mobility Commercial Cover: Monthly
# 505277  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 700836  Motor Comprehensive  Mobility Commercial Cover: Monthly
#
#        StatutoryClass StatutoryRiskType TotalPremium  TotalClaims ProfitMargin
# 522978     Commercial     IFRS Constant     4.901842     0.000000        100.0
# 294721     Commercial     IFRS Constant    21.929825  2289.473684     -10340.0
# 468534     Commercial     IFRS Constant     4.173509     0.000000        100.0
# 638159     Commercial     IFRS Constant   305.323333     0.000000        100.0
# 95457      Commercial     IFRS Constant     2.352632     0.000000        100.0
# 505277     Commercial     IFRS Constant     7.312105     0.000000        100.0
# 700836     Commercial     IFRS Constant     1.649035     0.000000        100.0
#
# [7 rows x 47 columns]

# %%
margin_t_stat, margin_p_value = PostalCode_analysis(df_clearned)
print("T-statistic (Gender):", margin_t_stat)
print("P-value (Gender):", margin_p_value)
# Out:
# T-statistic (Gender): nan
# P-value (Gender): nan
# c:\Users\ephre\Documents\AlphaCare-Insurance-Solutions\scripts\AB_Hypothesis_Testing.py:40: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, p_value = ttest_ind(male_claims, female_claims, equal_var=False)

# %%
alpha = 0.05  # significance level
if margin_p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the groups.")
# Out:
# Fail to reject the null hypothesis: No significant difference between the groups.
